# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/rainu1729/data-analysis/blob/master/Pandas_analysis.ipynb)

# %% [markdown]
# # **Learning Python for data analysis**

# %%
import numpy as np
import pandas as pd

from pandas import Series, DataFrame

# %%
from alpha_vantage.timeseries import TimeSeries

# %%
## the index type for pandas dataframe can be given here
ts = TimeSeries(key='553VVIHW6JPKL9WJ',output_format='pandas',indexing_type='date')

# %%
#fetch the daily adjusted(to accomodate for stock splits) stock price outputsize full or compact
data,meta_data = ts.get_daily_adjusted(symbol='NSE:TCS',outputsize='compact') 

meta_data
# Out:
# {'1. Information': 'Daily Time Series with Splits and Dividend Events',
#  '2. Symbol': 'NSE:TCS',
#  '3. Last Refreshed': '2018-10-15',
#  '4. Output Size': 'Compact',
#  '5. Time Zone': 'US/Eastern'}

# %%
##data['2. high']

import matplotlib.pyplot as plt

xvals = data.index.values
yvals =  data['1. open']
y2vals =  data['2. high']
plt.plot(xvals,yvals,label ='open')
plt.plot(xvals,y2vals,label ='high')

# %%
data.count()
# Out:
# 1. open                 3502
# 2. high                 3502
# 3. low                  3502
# 4. close                3502
# 5. adjusted close       3502
# 6. volume               3502
# 7. dividend amount      3502
# 8. split coefficient    3502
# dtype: int64
